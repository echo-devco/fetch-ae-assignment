# %%
import duckdb

# %%
receipts_df = duckdb.read_json('https://fetch-hiring.s3.amazonaws.com/analytics-engineer/ineeddata-data-modeling/receipts.json.gz')
print(receipts_df.columns)
receipts_df.describe
# Out:
# ['_id', 'bonusPointsEarned', 'bonusPointsEarnedReason', 'createDate', 'dateScanned', 'finishedDate', 'modifyDate', 'pointsAwardedDate', 'pointsEarned', 'purchaseDate', 'purchasedItemCount', 'rewardsReceiptItemList', 'rewardsReceiptStatus', 'totalSpent', 'userId']
# ...

# %%
for c in receipts_df.columns:
    print(c)
# Out:
# _id
# bonusPointsEarned
# bonusPointsEarnedReason
# createDate
# dateScanned
# finishedDate
# modifyDate
# pointsAwardedDate
# pointsEarned
# purchaseDate
# purchasedItemCount
# rewardsReceiptItemList
# rewardsReceiptStatus
# totalSpent
# userId

# %%
users_df = duckdb.read_json('/Users/seanmatthews/Projects/fetch-ae-assignment/seeds/users.json')
print(users_df.columns)
users_df.describe
# Out:
# ['_id', 'active', 'createdDate', 'lastLogin', 'role', 'signUpSource', 'state']
# <bound method PyCapsule.describe of ┌────────────────────────────────────┬─────────┬──────────────────────────┬──────────────────────────┬─────────────┬──────────────┬─────────┐
# │                _id                 │ active  │       createdDate        │        lastLogin         │    role     │ signUpSource │  state  │
# │       struct("$oid" varchar)       │ boolean │  struct("$date" bigint)  │  struct("$date" bigint)  │   varchar   │   varchar    │ varchar │
# ├────────────────────────────────────┼─────────┼──────────────────────────┼──────────────────────────┼─────────────┼──────────────┼─────────┤
# │ {'$oid': 5ff1e194b6a9d73a3a9f1052} │ true    │ {'$date': 1609687444800} │ {'$date': 1609687537858} │ consumer    │ Email        │ WI      │
# │ {'$oid': 5ff1e194b6a9d73a3a9f1052} │ true    │ {'$date': 1609687444800} │ {'$date': 1609687537858} │ consumer    │ Email        │ WI      │
# ...

# %%
for c in users_df.columns:
    print(c)
# Out:
# _id
# active
# createdDate
# lastLogin
# role
# signUpSource
# state

# %%
brands_df = duckdb.read_json('https://fetch-hiring.s3.amazonaws.com/analytics-engineer/ineeddata-data-modeling/brands.json.gz')
print(brands_df.columns)
brands_df.describe
# Out:
# ['_id', 'barcode', 'category', 'categoryCode', 'cpg', 'name', 'topBrand', 'brandCode']
# <bound method PyCapsule.describe of ┌────────────────────────────────────┬──────────────┬──────────────────────┬──────────────────┬───────────────────────────────────────────────────────────┬───────────────────────────┬──────────┬───────────────────────────────┐
# │                _id                 │   barcode    │       category       │   categoryCode   │                            cpg                            │           name            │ topBrand │           brandCode           │
# │       struct("$oid" varchar)       │   varchar    │       varchar        │     varchar      │   struct("$id" struct("$oid" varchar), "$ref" varchar)    │          varchar          │ boolean  │            varchar            │
# ...

# %%
for c in brands_df.columns:
    print(c)
# Out:
# _id
# barcode
# category
# categoryCode
# cpg
# name
# topBrand
# brandCode
